# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp('weather is good. How are you.')
# 打印词和词性
for token in doc:
    print(f'{token}-{token.pos_}')
# Out:
# weather-NOUN
# is-AUX
# good-ADJ
# .-PUNCT
# How-SCONJ
# are-AUX
# you-PRON
# .-PUNCT

# %%
for sent in doc.sents:
    print(sent)
# Out:
# weather is good.
# How are you.

# %%
# 命名体识别
doc2 = nlp('I went to Paris where I met my old friend Jack')
for ent in doc2.ents:
    print(f'{ent}-{ent.label_}')
# Out:
# Paris-GPE
# Jack-PERSON

# %%
from spacy import displacy
displacy.render(doc2, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I went to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Paris
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  where I met my old friend
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jack
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# </div></span>

# %%
# 找到书中所有人的名字

text = ''

# %%
from collections import Counter,defaultdict

# %%
def count_person(doc):
    c = Counter()
    processed_text = nlp(doc)
    for ent in processed_text.ents:
        if ent.label_ == "PERSON":
            c[ent.lemma_] += 1 
    return c.most_common(10)

def get_doc(filename):
    with open(filename, mode='r') as f:
        return f.read()

doc = get_doc('./data/pride_and_prejudice.txt')
print(count_person(doc))
# Out:
# [('Elizabeth', 624), ('Darcy', 411), ('Jane', 280), ('Bennet', 245), ('Collins', 179), ('Bingley', 163), ('Wickham', 114), ('Lizzy', 94), ('Gardiner', 94), ('Lady Catherine', 81)]

# %%
common_terrorist_groups = [
    'taliban', 
    'al - qaeda', 
    'hamas',  
    'fatah', 
    'plo', 
    'bilad al - rafidayn'
]

common_locations = [
    'iraq',
    'baghdad', 
    'kirkuk', 
    'mosul', 
    'afghanistan', 
    'kabul',
    'basra', 
    'palestine', 
    'gaza', 
    'israel', 
    'istanbul', 
    'beirut', 
    'pakistan'
]

# %%
# 恐怖袭击分析
def read_file_to_list(file_name):
    with open(file_name, 'r') as file:
        return file.readlines()
terr_articles = read_file_to_list('./data/rand-terrorism-dataset.txt')
terr_articles_nlp = [nlp(art) for art in terr_articles]

# %%
# Out:
# ['taliban', 'al - qaeda', 'hamas', 'fatah', 'plo', 'bilad al - rafidayn']

# %%
count_dict = defaultdict(Counter)
for article_nlp in terr_articles_nlp:
    # 存储文章中的组织和犯罪地点
    groups = [ent.lemma_ for ent in article_nlp.ents if ent.label_ == "PERSON" or ent.label_ == "ORG"]
    locations = [ent.lemma_ for ent in article_nlp.ents if ent.label_ == 'GPE']
    # 留下关注的组织和地点
    care_groups = [ent for ent in groups if ent in common_terrorist_groups]
    care_location = [ent for ent in locations if ent in common_locations]
    print(groups)
    print(care_groups)
    # 计数组织和地点
    for group in care_groups:
        for location in care_location:
            count_dict[group][location] += 1
count_dict
# Out:
# ['the Santiago Binational Center']
# []
# []
# []
# ['GUATEMALA']
# []
# ['Chase Manhattan Bank', 'Trans-World Airways', 'the Bank of America']
# []
# ['anti-Castro Cubans', 'the Spanish National Tourist Office']
# []
# ['El Poder Cubano']
# []
# ['Montevideo']
# []
# ['El Poder Cubano']
# []
# ['Joseph Antoine', 'the Haitian Coalition', 'anti-duvalier']
# []
# ['the Australian National Tourist Office', 'El Poder Cubano']
# []
# ['the Mexican National Tourist Office']
# []
# ['El Poder Cubano', 'Aeronaves de Mexico']
# []
# ['Air France', 'El Poder Cubano']
# []
# ['Israel Airlines', 'the Popular Front for the Liberation of Palestine', 'the PFLP General Command', 'PFLP', 'the International Red Cross']
# []
# ['Ein Yahav']
# []
# ['Al Fatah']
# []
# ['kupre', 'FBI']
# []
# ['El Poder Cubano', 'Polancia']
# []
# ['USIS']
# []
# ['USIS']
# []
# ['USIS']
# []
# []
# []
# ['Olympic Airways', 'Olympic Airways']
# []
# ['Israel Airlines']
# []
# ['the Amerika Haus Library']
# []
# []
# []
# []
# []
# []
# []
# ['the Trans-Arabian Pipeline', 'PFLP']
# []
# ['tameion', 'USIS']
# []
# ['PAKISTAN', 'the Eritrean Liberation Front (ELF', 'Boeing', 'ELF', 'Ethiopian Airlines', 'ELF', 'Ethiopian Air Force']
# []
# ['PFLP']
# []
# ['PFLP', 'PFLP', 'George Habbash']
# []
# ['Arson', 'the U.S. Binational Commission Cultural Exchange']
# []
# ['the Calcutta Post Office', 'USIS']
# []
# []
# []
# ['theRevolutionary Movement', 'ALN (action for National Liberation', 'Charles Burke Elbrick', 'Elbrick', 'Elbrick']
# []
# ['Al Fatah', 'El Al Airlines', 'PFLP', 'Bonn &']
# []
# ['the Eritrean Liberation Front (ELF', 'Ethiopian Airlines', 'Mohammed Sayed']
# []
# []
# []
# ['IBM Corporation', 'General Electric Company']
# []
# ['the Bank of Boston']
# []
# ['the U.S. Peace Corps']
# []
# ['fap', 'Peronist Armed Forces']
# []
# ['fap', 'Peronist Armed Forces']
# []
# ['fap', 'Peronist Armed Forces']
# []
# ['fap', 'Peronist Armed Forces']
# []
# []
# []
# []
# []
# ['Spiro T. Agnew']
# []
# []
# []
# ['the Message Center']
# []
# ['Swissair']
# []
# []
# []
# ['United Arab Airlines']
# []
# ['Joaquin Waldemar Sanchez', 'Paraguay', 'Sanchez']
# []
# ['MANO', 'Yuri Pivovarov', 'MANO']
# []
# ['GUATEMALA', 'Karl von Spreti', 'Count von Spreti']
# []
# []
# []
# ['Israel Airlines']
# []
# []
# []
# []
# []
# ['Iberian Air Lines DC9']
# []
# ['ECUADOR', 'Guayaquil']
# []
# []
# []
# ['El Al']
# []
# ['USIS']
# []
# ['the Argentine Embassy']
# []
# ['BOAC']
# []
# ['the South African Consulate']
# []
# []
# []
# ['Aloisio Mares Gomide', 'Mitrione', 'Tupamaros', 'Dias Gomide', 'Dias Gomide', 'Tupamaros', 'Dias Gomide', 'Dias Gomide']
# []
# ['Pan American World Airways', 'Rudolfo Rivera Rios']
# []
# ['fap', 'the italian Hospital']
# []
# ['U.S. Embassy']
# []
# []
# []
# ['GREECE']
# []
# ['PFLP', 'Swissair', 'Pan American World Airways', 'TWA', 'Dawson Field', 'Israel Airlines', 'Patrick Arguello', 'FSLN', 'Leila Khaled', 'TWA', 'Khaled', 'PFLP', 'PFLP', 'PFLP', 'Trans World Airlines']
# []
# ['ELF']
# []
# ['John Stewart', 'the U.S. Cultural Affairs Adviser', 'PLO']
# []
# ['the USIS Binational Center in Sucre']
# []
# ['the Quebec Liberation Front', 'FLQ', 'James R. Cross', 'FLQ', 'FLQ', 'FLQ', 'FLQ', 'Pierre LaPorte', 'LaPorte', 'Cross', 'LaPorte', 'FLQ', "James Cross's", 'LaPorte', 'Jacques', 'Louise Cossette-Trudel', 'Jacques Lanctot', 'Louise Cossette-Trudel', 'Yves Langlois', 'James Cross', 'Langlois']
# []
# ['the U.S. Air Force']
# []
# ['USIS', 'Oruro', 'La Paz']
# []
# []
# []
# ['PERU']
# []
# []
# []
# ['PAKISTAN']
# []
# []
# []
# ['the Armed Commandos of Liberation']
# []
# ['Buenos Aires', 'the Peronist Armed Forces', 'FAP']
# []
# ['ETA', 'Eugene Beihl', 'Beihl', 'Beihl', 'Basques', 'Generalissimo Franco']
# []
# ['USIS']
# []
# ['Ankara University']
# []
# ['Tupamaros', 'Geoffrey M.S. Jackson', 'Jackson', 'Tupamaros', 'Jackson']
# []
# []
# []
# ["the People's Revolutionary Front", 'Esso', 'Caltex']
# []
# ['Information Service']
# []
# []
# []
# []
# []
# ['TPLA', "Turkish Peoples' Liberation Army", 'James Finlay', 'the Ankara Air Station']
# []
# ['Army']
# []
# ['the United Nations']
# []
# ['PAKISTAN', 'Dacca']
# []
# ['PAKISTAN', 'Dacca']
# []
# ['Izmir']
# []
# ['CENTO', 'CENTO']
# []
# []
# []
# ['ERP', 'uruguayan']
# []
# ['AMTORG', 'the Soviet Trading Corporation', 'JDL', 'UPI', 'JDL']
# []
# ['Luis Blanco', 'Adolfo Bello', 'ERP']
# []
# ['Luis Blanco', 'Adolfo Bello', 'ERP']
# []
# ['Luis Blanco', 'Adolfo Bello', 'ERP']
# []
# ['ERP']
# []
# []
# []
# ['JDL']
# []
# ['the Mexican Government Tourism Department']
# []
# []
# []
# []
# []
# ['JDL']
# []
# []
# []
# []
# []
# ['ECUADOR', 'Guayaquil']
# []
# []
# []
# ['UPI', 'U.N.', 'the Black Revolutionary Assault Team']
# []
# ['Chapinero']
# []
# []
# []
# ['Shah']
# []
# ['the Trans-Arabian Pipeline', 'Jordan']
# []
# ['Swift & Company', 'Chicago Bridge Company']
# []
# []
# []
# []
# []
# ['BSO (Black September Organization', 'Zaid Rifai']
# []
# []
# []
# ['JDL', 'Sol Hurok']
# []
# []
# []
# ['the Resistance, Liberation and Independence Organization', 'AAA']
# []
# ['the Black September Organization', 'Esso']
# []
# ['USIS']
# []
# ['ERP', 'Oberdan Sallustro', 'Fiat of Argentina', 'Fiat', 'Sallustro', 'Fiat', 'Fiat', 'Sallustro']
# []
# ['the Cuban Trade Office', 'Alejandro Del Valle']
# []
# ['the Secret Army Organization', 'the Guild Theater']
# []
# ['TPLA']
# []
# []
# []
# ['the Comite Argentino de Lucha Anti-Imperialisto']
# []
# ['the USIS Binational Center']
# []
# ['a South African Airways', 'Balantyre', 'Malawi', 'the anglo-American Mining Company']
# []
# ['TWA', 'the Committee of Coordination']
# []
# ['William Holder', 'Catherine Kerkow', 'Western Airlines', 'Holder', 'Holder', 'Black Panther', 'Holder', 'Catherine Kerkow']
# []
# ['IBM', 'Honeywell', 'the Bank of America', 'Honeywell']
# []
# []
# []
# ['Shafiq al-Hout', 'PLO', 'Marwan Dajani', 'Al Fatah', 'Abu al-Hassan', 'PLO']
# []
# ['Gassan Kanafani', 'PFLP', 'Al Hadef', 'PFLP']
# []
# ['the USIS Cultural Center']
# []
# ['George Edward Wright', 'George Brown', 'Melvin McNair', 'Jean Allen McNair', 'Joyce T. Burgess', 'Black Panther Party', 'Delta Air Lines', 'Delta', 'American Black Panthers', 'Melvin McNair', 'Jean McNair', 'George Brown', 'Joyce Tillerson']
# []
# []
# []
# ['Air France B747']
# []
# ['USIS']
# []
# []
# []
# ['Venezuelan Airlines', 'Cyprus', 'Atef Harkous', 'Hussein Harkous', 'Adnan Harkous']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['Shimon Peres', 'the Jerusalem Post Office', 'BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['BSO']
# []
# ['Masada, Action and Defense Movement']
# []
# ['BSO']
# []
# ['Awel Abdel Zwaiter', 'Zwaiter']
# []
# ['Richard Nixon', 'Melvin Laird', 'State', 'William Rogers', 'suspicious israeli postal']
# []
# ['Richard Nixon', 'Melvin Laird', 'State', 'William Rogers', 'suspicious israeli postal']
# []
# ['PFLP']
# []
# ['the Pan American Airways']
# []
# ['International Trade Fair', 'Pan American World Airways']
# []
# []
# []
# ['Ethiopian Airlines']
# []
# []
# []
# []
# []
# ['the American University of Beirut']
# []
# ['CYPRUS', 'Al Fatah', 'Hussein Abad al-Khair', 'KGB']
# []
# ['the spanish', 'Banco Popular']
# []
# ['the Indian High Commission', 'Indira Ghandi']
# []
# ['BSO']
# []
# ['Israel Airlines', 'the First Israel Bank and Trust Company', 'the Israel Discount Bank', 'FBI', "Golda Meir's", 'PLO']
# []
# ['EAN', 'Greek Anti-dictatorial Youth']
# []
# ['BSO', 'Ziyad Al Hilu', 'BSO', 'Wasfi Tal']
# []
# ['Basil Raoud al-Kubaisi', 'PFLP', 'the Mossad Wrath']
# []
# ['CYPRUS', 'Zayad Murchesi', 'Arafat', 'Hussein Abad al-Khair']
# []
# ['terrorist', 'the Trans-Arabian Pipeline', 'Zahrani', 'PFLP']
# []
# []
# []
# ['IBM Corporation']
# []
# ['the british European Airways']
# []
# ['Pan American World Airways']
# []
# []
# []
# []
# []
# ['Lewis Hawkins']
# []
# ['PERU']
# []
# ['the El Al Israel Airlines', 'the Organization of Victims of Occupied Territories']
# []
# ['PERU']
# []
# ['the Organization of American States']
# []
# ['ECUADOR']
# []
# []
# []
# ['PARAGUAY', 'Ian Martin', "Liegib's Meat Company", 'ERP', 'Martin', 'Colorado Party', 'Martin']
# []
# []
# []
# ['BSO']
# []
# []
# []
# ['AUSTRIA', 'the Eagles of the Palestinian Revolution', 'Al Fatah', 'Schoenau Castle']
# []
# ['the National Liberation Army of Colombia', 'International Mining Company', 'International Mining']
# []
# ['Coca-Cola', 'Firestone Tire', 'Rubber', 'Mercedes- Benz']
# []
# ['Socialist Revolutionary Organization', 'Bank of America', 'the Bank of America', 'John Crawford Maxwell', 'Adel Najin Abu-Asi', 'John Crawford Maxwell']
# []
# ['ITT']
# []
# ['the Liberation of Palestine', 'KLM Royal Dutch Airlines', 'KLM']
# []
# ['a Communist Youth Movement']
# []
# ['Pan American World Airways', 'Lufthansa German Airlines', 'PLO']
# []
# ['Cuban National Liberation']
# []
# ['the Spanish', 'Chamber of Commerce']
# []
# []
# []
# []
# []
# ['PERU']
# []
# ['Pepsi-Cola and Union Carbide', 'Coca-Cola']
# []
# ['PAKISTAN', 'Moslem International Guerrillas', 'PIA']
# []
# ['Air France']
# []
# []
# []
# ['Dow Chemical']
# []
# []
# []
# ['the Cordoba USIS Binational Center']
# []
# ['Sears', 'El Marques', 'Bello Monte', 'Bandero Rojo (Red Flag']
# []
# ['the FLNC - National Front for the Liberation of Cuba']
# []
# ['Cubana de Aviacion', 'flnc']
# []
# ['Alfred Laun', 'the U.S. Information Service', 'ERP', 'Laun', 'fascist', 'CIA', 'Laun']
# []
# ['the Technical Military Academy', 'the Islamic Liberation Organization']
# []
# ['the Caribe Star', 'the jewish Defense League']
# []
# ['the USIS Regional Service Center', 'Socialist Revolutionary Movement']
# []
# ['Iberia Airlines', 'the First National Bank', 'Westbury Hotel', 'Iberia Airlines']
# []
# ['the Revolutionary Arab Youth Organization']
# []
# ['anti-duvalier haitian']
# []
# ['the Bank of London']
# []
# ['the First National City Bank', 'Bank of Boston', 'the Bank of America', 'Coca-Cola', 'Ford', 'Parke-Davis', 'Xerox']
# []
# ['the First National City Bank', 'Bank of Boston', 'the Bank of America', 'Coca-Cola', 'Ford', 'Parke-Davis', 'Xerox']
# []
# ['the Bank of London']
# []
# ['An-Nahar', 'PLO', 'Yasser Arafat']
# []
# ['Alfredo Canales', 'Marquis', 'the Lebanese Revolutionary Socialist Organization']
# []
# []
# []
# ["L'Aurore", 'the jewish Social Fund', 'PFLP', 'Commando Muhammad Boudia', 'PFLP', 'BSO']
# []
# ['the Spanish Bank', 'Iberia Airlines', 'GARI']
# []
# ['Fidel Castro']
# []
# ['Chung Hee Park', 'Mun Se Kwang', 'Park', 'the Korean Youth League', 'Park']
# []
# ['TWA']
# []
# []
# []
# ['Salta']
# []
# ['the japanese', 'United Red Army', 'Jacques Senard', 'Yutaka Furuya', 'Red Army', 'Furuya', 'PLO', 'PLO']
# []
# ["Juan Peron's", 'Ford', 'Peugeot', 'IKA', 'Goodyear', 'Firestone Tire', 'Eli Lilly', 'Union Carbide Battery Company', 'Bank of Boston', 'Chase Manhattan Bank', 'Xerox Corporation', 'Coca-Cola', 'Pepsi-Cola']
# []
# ["Juan Peron's", 'Ford', 'Peugeot', 'IKA', 'Goodyear', 'Firestone Tire', 'Eli Lilly', 'Union Carbide Battery Company', 'Bank of Boston', 'Chase Manhattan Bank', 'Xerox Corporation', 'Coca-Cola', 'Pepsi-Cola']
# []
# ["Juan Peron's", 'Ford', 'Peugeot', 'IKA', 'Goodyear', 'Firestone Tire', 'Eli Lilly', 'Union Carbide Battery Company', 'Bank of Boston', 'Chase Manhattan Bank', 'Xerox Corporation', 'Coca-Cola', 'Pepsi-Cola']
# []
# ['Montoneros', 'Juan', 'Jorge Born', 'Bunge and Born Company', 'Borns', 'bear', 'Juan Born', 'Jorge Born', 'Montoneros', 'Bunge', 'Born']
# []
# ['Carlos Prats Gonzalez', 'the Chilean Army', 'Salvador Allende', 'Buenos Aires']
# []
# ['Face-Standard', 'ITT', 'Avis Milan', 'ITT']
# []
# ['PERU', 'terrorist', 'Coca-Cola']
# []
# ['the National Cash Register Company', 'the Arab Communist Organization']
# []
# ['the USIS Binational Center']
# []
# ['USDAO']
# []
# ['IBM', 'Minnesota Mining and Manufacturing Company', 'Bank of America', 'State', 'Henry Kissinger', 'the World Food Conference']
# []
# ['Fernando Lopez Muino']
# []
# ['the Pan American Union', 'the Organization of American States', 'United Press International', 'the Cuban Movement c-4']
# []
# ['the Holger Meins Kommando']
# []
# ['UNITED ARAB emirate', 'British Airways VC-10', 'UAE', 'PLO', 'Werner Gustav Kehl', 'PLO', 'PLO', 'PLO', 'PLO']
# []
# []
# []
# ['Al Fatah', 'Rihaniya']
# []
# ['Rosh Hanikra', 'PLO']
# []
# ['PFLP']
# []
# ['the Minnesota Mining and Manufacturing Company', 'the Youth Action Group']
# []
# ['Ben Yehuda Street', 'PDFLP']
# []
# ['Air India', 'Josef Homolov']
# []
# ['the Baader Solidarity Group', 'Holger Meins Brigade', 'Ulrike Meinhof Commando', 'Mercedes']
# []
# ['USIS']
# []
# ['ASALA', 'the World Council of Churches']
# []
# ['UNIDOS', 'the Cuban Action Commandos']
# []
# ['Campus Banquet Hall']
# []
# ['Rosario', 'the First National Bank of New York', 'the Boston Bank']
# []
# []
# []
# ['Peter Lorenz', 'the Christian Democratic Union Party', 'Lorenz', 'Lorenz', 'the Movement of June 2', 'Peter Lorenz', 'the Movement of June 2', 'Lufthansa', 'Foreign Ministry', 'Lorenz', 'Lorenz']
# []
# ['the Savoy Hotel', 'the Youth Center', 'the Savoy Hotel', 'UN', 'Hillarion Capucci', 'Hotel', 'State', 'Henry Kissinger', 'Al-Fatah', 'State', 'Henry Kissinger', 'Fatah', 'Anwar Sadat脮s', 'Kissinger']
# []
# []
# []
# ['the Cuban Action Commandos']
# []
# ['USIS']
# []
# ['Reuters', 'the Charles Martel Group']
# []
# ['the Anti-Japan Armed Front of East Asia']
# []
# ['ETA', 'Jose Antonio Urruticoechea', 'ETA']
# []
# ['IBM', 'the International Revolutionary Group']
# []
# []
# []
# ['U.S. Air Force', 'Paul R. Shaffer', 'Jr.', 'John H. Turner', 'Lewis Hopkins', 'the U.S. Military Mission']
# []
# ['the Mexican Consulate']
# []
# ['Ford', 'the Bank of America', 'the Goodyear Tire Company', 'ITT']
# []
# ['ETA']
# []
# ['GUATEMALA']
# []
# ['Michael Moukarbel', 'Carlos', 'Moukarbel', 'Carlos', 'speculation', 'Carlos', 'Ilich Ramirez Sanchez']
# []
# ['kidnapper', 'Steven C.  Campbell', 'James J. Harrell', 'U.S.-run kagnew', 'Collins International Service Company', 'Rockwell Corporation', 'ELF', 'the Popular Liberation Front', 'the u.s.-equipped Ethiopian Air Force', 'ELF']
# []
# ['Roubaix']
# []
# ['the Japanese Red Army', 'the American International Assurance Building', 'Robert Stebbins', 'Frederick Bergenstrahle', 'Red Army', 'Japan Airlines', 'Boeing', 'the Red Army', 'Red Army', 'Frederik Bergenstrahle', 'Takeo Miki', 'Red Army', 'Red Army', 'Red Army']
# []
# ['Donald E. Cooper', 'Sears, Roebuck', 'Cooper', 'Cooper']
# []
# ['the Algerian Opposition']
# []
# ['Navy', 'ELF']
# []
# ['Boise-Cascade']
# []
# ['Thomas C. Bowidowicz', 'Navy', 'David Strickland', 'Specialist 5 of the Army', 'ELF', 'the revolutionary council', 'Haile Selassi', 'the State Department', 'ELF', 'the Government of Ethiopia', 'Massawa', 'the u.s.-equipped Ethiopian Air Force']
# []
# ['Speculation', 'PLFP', 'PLO', 'Guerrillas', 'Mahmoud Abdul Ghaffar', 'Ghaffar', 'PLO', 'PLO', 'Ahmed Lufti Mitwalli', 'PLO', 'Yasir Arafat', 'Popular Front for the Liberation of Palestine', 'Anwar Sadat']
# []
# ['Xerox Argentina']
# []
# []
# []
# ['IRA', 'Tiede Herrema', 'the Dutch Ferenka Company', 'Irish Republican Army', 'Brigitte Rose Dugdale', 'Miss Dugdale', 'Kevin Malin', 'Jim Hyland', 'Tiede Herrema', 'Herrema', 'Superintendent Lawrence Wrenn', 'Brian McGowan', 'John Vincent Walsh']
# []
# ['the United Nations High Commission for Refugees in Buenos Aires', 'Robert Mueller', 'the UN High Commission for Refugees']
# []
# []
# []
# []
# []
# ['AUSTRIA', 'Danis Tunaligil', 'the Armenian Liberation Army', 'British-']
# []
# ['PLO']
# []
# ['Michael Ross', 'United Press International']
# []
# ['Rue Clemenceau']
# []
# []
# []
# []
# []
# ['DFLP', 'Ramat Magshimim']
# []
# ['Cuban Power', 'the Frente de Liberacion Nacional Cubana', 'Bahamassair']
# []
# ['the Free South Moluccan Youths', 'Beilen']
# []
# ['FBI', 'Social Security', 'State', 'the Miami Police Department Headquarters', 'Rolando Otero']
# []
# ['FBI', 'Social Security', 'State', 'the Miami Police Department Headquarters', 'Rolando Otero']
# []
# ['the Portuguese Liberation Army']
# []
# ['Chapinero']
# []
# ['Richard Welch', 'the Revolutionary Organization of November 17', 'EOKA']
# []
# ['Eastern', 'TWA', 'PLO', 'PLO']
# []
# ['Middle East Airlines']
# []
# []
# []
# []
# []
# ['PORTUGAL', 'the Anti-Communist Action Front', 'Ribakovatye']
# []
# ['KENYA', 'PFLP', 'EL AL', 'Idi Amin', 'the Kenya Security Service', 'PFLP', 'Air France', 'Entebbe']
# []
# ['Iran Air']
# []
# []
# []
# ['Dzhordano Bruno', 'Anguilla Cays', 'Anti-Castro cuban']
# []
# ['El Marques']
# []
# ['the Unified Liberation Front of New Algeria']
# []
# ['the jewish Armed Resistance', 'Defense League']
# []
# ['Aeroflot']
# []
# []
# []
# ['Ford']
# []
# ['Philips Electronics']
# []
# ['the United Nations', 'the jewish Armed Resistance']
# []
# ['the United Nations', 'Associated Press', 'ABC News']
# []
# []
# []
# []
# []
# ['Vicente Dopico', 'Castro', 'the Sons of Giron Movement']
# []
# ['the Armed Communist Formation', 'Chevron Oil Italiano', 'Chevron', 'Standard Oil of']
# []
# []
# []
# ['the Front International Revolutionnaire', 'Rothschild']
# []
# []
# []
# ['the Communist Party', 'United Nations', 'the Daily News', 'the jewish Armed Resistance Strike Unit']
# []
# ['Fiat']
# []
# ['Kocker', 'Thyussen']
# []
# ['German Academy Building', 'Ulrike Meinhof']
# []
# ['Ulrike Meinhof']
# []
# ['the FRG Consulate']
# []
# ['Edouard Saab', "L'Orient le Jour", 'Henry Tanner', 'the New York Times']
# []
# ['Essen']
# []
# []
# []
# ['PFLP']
# []
# ['the Turkish Consulate']
# []
# []
# []
# ['KUWAIT', 'Arafat', 'the Kuwait Criminal Court']
# []
# ['the United Nations', 'Associated', 'Omega']
# []
# []
# []
# []
# []
# ['PFLP', 'Air France', 'Entebbe', 'Air France', 'Entebbe']
# []
# ['Dusseldorf', 'Gunman Marko Krpan', 'Pavle Perovic']
# []
# ['Cubana Airlines']
# []
# ['ex-Waffen S.S.', 'Joachim Peiper']
# []
# ['Ramat Gan']
# []
# ['PORTUGAL']
# []
# ['the International Che Guevara Organization']
# []
# ['the Bogota International Trade Fair', 'Leon Arboleda', 'EPL', 'Popular Liberation Army', 'the Trade Fair', 'Operation Tigre de Papel (Paper Tiger']
# []
# ['Rolf Pohle']
# []
# []
# []
# []
# []
# ['Mohammed Ali Haitham']
# []
# ['CORU', 'the Cuban Embassy', 'CORU']
# []
# []
# []
# ['Cubana', 'Belisario Porras International Airport', 'Cubana', 'the Anti-Castro Command']
# []
# ['AUSTRIA']
# []
# ['Renault', 'IBM', 'Ford', 'Montoneros']
# []
# ['TRINIDAD', 'CORU', 'Guyana']
# []
# ['Chrysler', 'Montoneros', 'Chrysler', 'Ford']
# []
# ['Croatia', 'TWA', 'Zvonko Busic', 'Julienne']
# []
# ['Honeywell International', 'Speculation', 'Salvador Allende']
# []
# ['Guerrillas', 'the Ford Motor Company', 'Montoneros']
# []
# []
# []
# ['Westinghouse']
# []
# ['the Ghassan Kanafani Commandos', 'the Bank of America', 'Avis']
# []
# ['the Ghassan Kanafani Commandos']
# []
# ['the Basque Pastor']
# []
# ['the syrian Arab Airlines']
# []
# ['Ali Hassan Salamah']
# []
# ['PAKISTAN', 'PLO']
# []
# ['Pan Am', 'Izmir']
# []
# ['Eko', 'Spiro', 'lebanese Christian Group']
# []
# ['Aldo Vera Serafin', 'Castro', 'CORU', 'Orlando Bosch']
# []
# ['the Reza REZAI International Brigades']
# []
# ['Mahir Cayan']
# []
# ['FSLN']
# []
# ['usaf', 'usaf']
# []
# []
# []
# ['Abd-al-Halim Khaddam']
# []
# ['Chrysler', 'Communist League']
# []
# ['Army']
# []
# ['Huber Matos', 'Matos', "Fidel Castro's", 'Matos', 'State Department', 'Jorge Montes']
# []
# ['BANGLADESH', 'USIS']
# []
# ['Duraflex Corporation', 'Mitchell Andreski', 'Communist League']
# []
# ['Mario Bernal Londono']
# []
# []
# []
# ['PERU']
# []
# []
# []
# ['USIS']
# []
# ['George de Mohrenschildt', 'Lee Harvey Oswald', "John Kennedy's", 'Oswald']
# []
# ['ZAIRE', 'Glen J. R. Eschtruth', 'the United Methodist Mission Hospital']
# []
# []
# []
# ['the Action Front for the Liberation of the Baltic Countries']
# []
# []
# []
# []
# []
# ['the USIS Cultural Center', 'GRAPO']
# []
# ['Mackey International Airlines', 'UPI', 'castro', 'Mackey Airlines', 'Joseph Mackey']
# []
# ['May Armenian Organization']
# []
# ['UN', 'the yugoslav Mission', 'the United Nations', 'Jaksa Petric', 'Vladimir Dizdar', 'Radimir Medic']
# []
# ['CYPRUS', 'George Atallah', 'Fatah', 'PLO']
# []
# ['UNITED ARAB emirate']
# []
# []
# []
# ['the French Cultural Institute', 'the October Group of Anti-Fascist Resistance']
# []
# ['the U.S. Armed Forces Post Exchange']
# []
# ['PERU', 'the International Commandos of Zone 6', 'CORU']
# []
# ['Swissair', 'Petra Krause']
# []
# ['RHODESIA', 'Woolworth', 'TNT']
# []
# []
# []
# ['Chamber of Commerce', 'Herbert Kappler']
# []
# ['Sears']
# []
# ['the Santiago Binational Center', 'Resistencia Popular']
# []
# ['Sears Roebuck', 'General Motors', 'Colgate Palmolive']
# []
# ["the Indian High Commission's", 'P.R. Sarkar', 'Ananda Marga']
# []
# ['Fontainebleau', 'Eden Roc', 'the Sheraton Four Ambassadors', 'the Associated Press', 'the Luis Boitel Commandos', 'Castro']
# []
# ['the Panama Canal Treaty']
# []
# []
# []
# ['the First National Bank of Chicago', 'the Arab Communist Organization', 'the Bank of America']
# []
# ['the Arab Revolutionary Movement']
# []
# ['Anonymous', 'Andreas Baader']
# []
# ['Metin Yalma']
# []
# ['the Andreas Baader Commando']
# []
# []
# []
# []
# []
# ['Baader-Meinhof Gang', 'Mercedes']
# []
# ['Polisario']
# []
# ['Polisario Front', 'the Polisario Front', 'UN', 'Kurt Waldheim', 'the Polisario Front', 'UN', 'Waldheim']
# []
# ['the Egyptian Embassy']
# []
# []
# []
# ['the Movement for the Self-Determination and Independence of the Canary Islands', 'the High Command', 'the spanish Forces']
# []
# ["Tal az-Za'tar", 'Bank']
# []
# ['CYPRUS', 'Akrotiri']
# []
# ['Gunfire', 'Ford', 'Chrysler', 'Mercedes-Benz']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['Egyptair']
# []
# ['the Almacen el Espanol']
# []
# ['EOD', 'RSO']
# []
# ['FBI']
# []
# []
# []
# []
# []
# ['the Beagle Channel']
# []
# ['the U.S. Cultural Center', 'TRT', 'the U.S. Cultural Center']
# []
# ['FROLINAT']
# []
# ['the Arab Revolutionary Army', 'the Arab Revolutionary Army']
# []
# ['PAKISTAN']
# []
# []
# []
# ['the World Bank', 'the jewish Committee for Concern']
# []
# ['Lufthansa', 'the Andreas Baader Brigade', 'the German Liberation Popular Front']
# []
# ['terrorist', 'Andreas Baader', 'Lufthansa']
# []
# []
# []
# ['secret Armenian Army']
# []
# ['Terpsithea', 'Glifadha']
# []
# ['the Tarsus American School', 'TIP']
# []
# ['PAKISTAN', 'the U.S. Consulate', 'Zulfiqar Ali Bhutto']
# []
# ['the spanish-American Cultural Center']
# []
# ['DJIBOUTI', 'Young Afar', 'the National Independence Union', 'Rene Boucault']
# []
# ['UPI', 'the Polisario Liberation Front']
# []
# ['the Organization of the Sons of Southern Lebanon', 'Mahmud Awada', 'Francis Meloy', 'Jr.', 'Robert Waring']
# []
# []
# []
# ['PORTUGAL', 'the Action Group for Communism']
# []
# ['the Sanyati Mission Hospital']
# []
# []
# []
# ['the Palestine Liberation Organization', 'Hans-Dietrich Genscher', 'Mondale']
# []
# ['Juan Echave', 'Echave', 'Rosario', 'Echave', 'Triple A']
# []
# ["Yasir Arafat's", 'Fatah', 'the Fatah Revolutionary Council', 'Yusuf', 'Ali Darwaish', 'Ahmad Hassan', "Din Mustafa Shakir '", 'Imad Ash-Shaykh']
# []
# ['Taha Ahmed al-Dawood']
# []
# ['PAKISTAN', 'the Palestine Liberation Organization', 'Fatah', "Abu Nidal's"]
# []
# ['KUWAIT', 'PLO', 'Yasir Arafat', 'Arafat', "Al-Masna'", 'Arafat']
# []
# ['the Palestinian Liberation Front', 'PLF', 'Arafat脮s Fatah', 'UN', 'Fatah', 'PLF', 'the Popular Front for Liberation of Palestine', 'PFLP']
# []
# ['Stjepan Bilandzic', 'Bilandzic', 'McLaughlin Evan Bilandzic', "the Croatian People's Resistance", 'Bozo Kelava', 'Mile Kodzoman', 'Werner Ickstadt']
# []
# ['IRA']
# []
# ['IRA']
# []
# ['General Motors', 'Buenos Aires']
# []
# ['PERU', 'Roberto Fanjul', 'Peruvian Anti-Communist Alliance', 'Fanjul']
# []
# ['Popular Liberation Forces', 'FPL', 'Yankee']
# []
# ['GUATEMALA', 'the Nicaraguan Airlines Company']
# []
# ['the Cuban Embassy', 'Il Tempo', 'the Nicaraguan Embassy', 'the Cuban Embassy']
# []
# []
# []
# ['Bell Helicopter International']
# []
# []
# []
# ['VW', 'the german Red Army Faction', 'RAF']
# []
# ['Chalchuapa', 'Manuel de Jesus Lopez', 'the Farabundo Marti Popular Liberation Forces', 'FPL']
# []
# ['NETHERLANDS']
# []
# ['Konstanz']
# []
# ['McDonald', 'the Farabundo Marti Popular Liberation Forces', 'FPL']
# []
# ['FBI']
# []
# ['Guerrillas', 'Fuerzas Armadas de Resistencia Nacional', 'Ian Massie', 'Michael Chatterton', 'Britons', 'the Human Rights Commission', 'Suzuki', 'Manuel Rivera', 'Lil Milagro Ramirez', 'FPL', 'Popular Forces of Liberation']
# []
# []
# []
# ['the Synthetics Industry of Central America', 'INSINCA', 'Tore Textile', 'the Armed Forces of National Resistance (FARN']
# []
# ['Commandos of the Democratic Front for the Liberation of Palestine']
# []
# ['PLO']
# []
# ['Texaco', 'Paul Grimm', 'Malek Bourojerdi', 'KGB']
# []
# ['Izmir']
# []
# ['PORTUGAL', 'Sierra']
# []
# ['Jose M.  Pagoaga', 'ETA']
# []
# ['an Organization of American States', 'Carlos Romero', 'the United Popular Action Front']
# []
# ['U.S. Air Force Major']
# []
# ['terrorist', 'the Guatemalan Embassy', 'the Sandinist National Liberation Front (FSLN']
# []
# ['Adolph Dubs', 'Dubs', 'American Embassy', 'the American Embassy', 'Dubs', 'State', 'Warren Christopher']
# []
# ['the Movement of the Revolutionary Left', 'MIR']
# []
# []
# []
# ['Carter']
# []
# ['Belgium National Bank', 'Andre Michaux', 'Sykes', 'Michaux', 'NATO', 'Red Brigade']
# []
# ['the U.S. Embassy']
# []
# []
# []
# ['ETA', 'the Credit Lyonnais']
# []
# []
# []
# ['CYPRUS', 'the israeli Embassy']
# []
# ['Mario Forgiarini', 'Frank Striskovich', 'Rossmoor and Cerritos', 'FBI']
# []
# ['Carlos Muniz', 'Varela', 'Muniz']
# []
# ['IDF']
# []
# ['the ICA Center', 'U.S. International Communication Agency']
# []
# ['GRAPO', 'Valencia', 'Ford']
# []
# ['AUSTRIA', 'the Eagles of the Palestine Revolution']
# []
# ['Al Fatah']
# []
# ['leftist', 'Maoist Popular Liberation Army', 'EPL']
# []
# ["the People's Revolutionary Bloc", "the People's Revolutionary Bloc", 'Agence France Presse', 'the United Nations', 'Michel Dondenne', 'Julio Esquivel', 'the Popular Revolutionary Bloc']
# []
# ['the Venezuelan Embassy', 'Santiago Ochoa', 'the Popular Revolutionary Bloc']
# []
# ['the Popular Liberation Forces']
# []
# ['the Farabundo Marti Popular Liberation Forces', 'IBM']
# []
# ['International Communication Agency']
# []
# ['David Goodman']
# []
# ['the Robert E. D. Straker Commando', 'the Territorial Resistance Army', 'Aeroflot']
# []
# ['Alexander Haig', 'NATO', 'Haig', 'Haig', 'the Red Army Faction', 'RAF', 'the Julien Lehant Brigade', 'BELGA', 'the Irish Republican Army']
# []
# ['FSLN', 'Colin Avery']
# []
# ['Turkish Airlines', 'Turkish Tourist Office', 'Agence France- Presse']
# []
# ['israeli Army']
# []
# ['the libyan-Tunisian Bank', 'Sadr Brigade', 'Imam Mousa al Sadr', 'Sadr']
# []
# ['Marvin Weissman']
# []
# ['the libyan News Agency']
# []
# ['Jaime Conde Feijoo']
# []
# ['the Revolutionary Guards']
# []
# []
# []
# []
# []
# []
# []
# ['dc-8', 'Qaddafi', 'Imam Musa Sadr']
# []
# ['Mercedes Benz', 'the U.S. Embassy']
# []
# ['U.S. Army']
# []
# ['Dennis McDonald', 'Fausto Bucheli', 'the Beckman Instrument Company', 'McDonald', 'Jose Luis Paz Tartara', 'the Revolutionary Party of Central American Workers', 'the Beckman Electronics Company', 'Los Angeles Times', 'New York Times', "the Central American Workers'", 'Revolutionary Party', 'Fred Rayne', 'Beckman']
# []
# []
# []
# []
# []
# ["the French Embassy's", 'Il Messaggero', 'the Bank of France']
# []
# ["the Bank of America's", 'the Farabundo Marti Popular National Liberation Forces']
# []
# ['Eulalio Jose Negrin']
# []
# ['the Popular Liberation Forces', 'McDonald']
# []
# ['Trans World']
# []
# ['PLO']
# []
# ['the armenian Secret Army', 'British Airways', 'Trans World Airlines', 'ASALA', 'John Paul']
# []
# []
# []
# ['Qaddafi']
# []
# ['Pan American World Airways', 'British Airways', 'Philippine Airways']
# []
# ['American Peace Corps', 'Deborah Loft', 'the Popular Leagues', 'Loft']
# []
# ['Mobutu Dongo Yema', 'Mobutu Sese', 'Mobutu']
# []
# ['ASALA', 'the Dina Boarding House', 'ASALA']
# []
# ['the Iraqi Embassy']
# []
# []
# []
# []
# []
# ['Commando for Justice', 'TWA', 'British Airways', 'Swissair', 'Sabena']
# []
# ['Boeing', 'Iman Mousa Sadr']
# []
# ['Air France']
# []
# ['Turkish Airlines']
# []
# ['Victor Sanchez-Mesa', 'Juste', 'Popular Leagues', 'the Red Cross', 'the Organization of American States', 'the Spanish Embassy', 'the Spanish Mission', 'Leagues', 'Leagues', 'Popular Revolutionary Bloc']
# []
# ['the Panamanian Embassy']
# []
# ['U.S. Embassy']
# []
# ['the Secret Armenian Army', 'the Liberation of Armenia', 'Associated Press', 'Lufthansa']
# []
# ['Said Ali Salman', 'Max Mazin', "B'nai b'rith"]
# []
# ['Turkish Airlines', 'the Armenian Secret Army']
# []
# ['the Angolan Mission to the United Nations', 'anti-castro cuban', 'UN']
# []
# ['U.N.', 'Raul Roa Kouri', 'UPI', 'FBI', 'Alberto Perez', 'Elizabeth', 'Eduardo Losado-Fernandez', 'Pedro Remon', 'FBI']
# []
# ['GUATEMALA']
# []
# ['the Justice Commandos', 'the armenian Genocide', 'Reuters']
# []
# ['Abdul Aref', 'Cafe de Paris', 'the libyan Embassy', 'the Libyan Revolutionary Committees']
# []
# ['PLO', 'PLO']
# []
# ['the Iranian Embassy', 'the Group of the Martyrs', 'Khomeini', 'Bani-Sadr', "commando of the Army's", 'the Special Air Service Regiment', 'SAS', 'Fowzi Nejad', 'Nicknamed Baby Face']
# []
# []
# []
# ['Omran el-Mehdawi', 'El-Mehdawi', 'Qaddafi']
# []
# ["Robert White's", 'White', "Roberto d'Abuisson"]
# []
# ['Mohammed Fezzani', 'Mezaroni Belgozem', 'Belgazem', 'Fezzani']
# []
# ['the Kurdish National Unity Party', 'Jalal Talabani']
# []
# ['Mujahedeen Islam']
# []
# ['Vladimir Sindjelic', 'the Washington Post', 'Paraguay']
# []
# ['the British Embassy']
# []
# ['Kenneth H.  Reysen', 'the Colgate-Palmolive company', 'Reysen']
# []
# []
# []
# ['GIN']
# []
# ['Fabio Ponce', 'Danli']
# []
# []
# []
# ['Chang Lin Lee']
# []
# ['the libyan Arab Airlines']
# []
# ['SNIA-Techint', 'the Committee for the Defense of the Islamic Revolution', 'de sauvegarde de la', 'Committee', 'MONDE']
# []
# ['John Gunther Dean', 'Dean', 'the United Nations', 'Dean', 'the Front for the Liberation of Lebanon from Foreigners']
# []
# ['the Guatemalan Embassy', "the People's Liberation Front", 'FPL']
# []
# ['the Organization of American States', 'the Revolutionary Democratic Front', 'OAS', 'OAS', 'OAS', 'OAS', 'OAS']
# []
# ['Sarita', 'Polisario']
# []
# []
# []
# ['the Marlim Mansion Hotel', 'the April 6 Liberation Movement', 'Ferdinand E.  Marcos', 'Marcos']
# []
# ['the Secret Army', 'the Liberation of Armenia']
# []
# ['the October Third Organization']
# []
# ['Turkish Airlines', 'the Armenian Secret Army', 'Scotland Yard']
# []
# ['a Swiss Tourist Office', 'the Organization of October 3rd']
# []
# ['the American Society of Travel Agents', 'Manilla', 'Fedinand Marcos', 'Marcos', 'Marcos', 'Victor Burns', 'Doris Nuval Baffrey']
# []
# ['PORTUGAL', 'the Unified democratic Front of Mozambique']
# []
# ['the Chilean Embassy', 'the Lorenzo Zelaya Guerrilla Commando']
# []
# ['Swiss Airlines', 'Swiss Tourist', 'the October Third Group', 'Agence France-Presse', 'the Armenian Secret Liberation Army', 'Party']
# []
# ['the Turkish Airlines', 'the armenian Secret Army', 'AP']
# []
# []
# []
# ['GUATEMALA', 'uruguayan', "the People's Guerrilla Army", 'EGP']
# []
# []
# []
# ['the Palestine Information Office', 'PIO', 'PLO', 'UPI', 'Hatikva Leumi']
# []
# ['PERU', 'the Chinese Embassy', 'Mao']
# []
# ['Moshe Dayan', 'Shlomo Levin', 'Erlangen', 'Frida Poshke', 'Lewin']
# []
# ['guadeloupe', 'Point-a-Pitre', "D'Estang", 'the Armed Liberation Group of Guadeloupe', 'GLA']
# []
# ['Swissair', 'TWA']
# []
# ['CYPRUS', 'Hamid Hindi', 'Cabinet', 'Moshe Antoine Bavli', 'the Popular Front for the Liberation of Palestine', 'Hindi', 'PFLP']
# []
# ['Ahmet Erdeyli', 'the Turkish Embassy', 'the Alex Yenikomeshian Commando', 'the Armenian Secret Army']
# []
# ['the the jewish Defense League', 'the American Revenge Committee', 'Khomeini', 'FBI']
# []
# ['the Associated Press', 'Alex Yenikomeshian', 'Suzy Mahseredjian', 'the Secret Army', 'the Liberation of Armenia', 'Vicken Tcharkhutian', 'ASALA']
# []
# ['Paul Goma', 'Nicolas Penescu', 'Serbran Orasco', 'Khrushchev', 'Goma', 'Penescu', 'the National Romanian Council', 'Exile', 'Orasco', 'the Conference on Security and Cooperation', 'Goma']
# []
# ['eagle of the Revolution']
# []
# ['remember Copernic', 'the Rue Copernic']
# []
# ['ETA/PM', 'Basque Fatherland', 'Liberty', 'Amnesty International', 'the Human Rights Commission', 'the Basque Parliament', 'the Spanish Parliament', 'ETA', 'ETA']
# []
# ['Anwar Sadat', 'Gaafar Nimeiri']
# []
# ['PAKISTAN', 'Pakistani International Boeing', 'Karachi', 'Al Zulfikar', 'pro-bhutto', 'Zia ul-Haq', 'Zulfikar Ali Bhutto', 'Tariq Rahim', 'Rahim', 'Bhutto', 'Zia', 'Salamullah Khan', "Pakistan People's Party", 'Enroute', 'Zia', 'Karmal']
# []
# ['Mohammad Saleh', 'the Iranian Student Association', 'Association']
# []
# ['Javier Chamorro Mora']
# []
# ['terrorist', 'the American Embassy', 'Carlos Aguero Echeverria Command', 'Sandinist', 'Somoza', "the People's Avant-Garde Organization"]
# []
# ['U.S. Embassy', "People's Liberation Forces", 'FPL', 'Frank Chapin', 'Reagan', 'Robert White']
# []
# ['U.S. Army', 'the Red Army Faction']
# []
# ['the French Embassy', 'the Mujaheddin Saff (the warrior', 'Mirage']
# []
# ['Air Force']
# []
# ['Embassy']
# []
# ['GUATEMALA']
# []
# ['GUATEMALA', 'Rubelsalto', 'ELF Aquitaine']
# []
# ['Pessach', 'Syrian Airlines', 'AFP', 'Pessach']
# []
# ['John Paul II', 'Mehmet Ali Agca', 'Agca', 'Agca', 'Agca', 'Agca', 'Mehmet Ali Agca', 'Serge Ivanov Antonov', 'Antonov']
# []
# ['Pan American World Airways', 'the Puerto rican Armed Resistance']
# []
# ['Turkish Airlines', 'Dev Sol']
# []
# ['the Armenian Cultural Center', 'the turkish Islamic Revolutionary Army']
# []
# ['the Palestinian Liberation Organization', 'PLO', 'the israeli Embassy', 'PLO', 'Naim Khader', 'Khader']
# []
# []
# []
# ['NATO', 'the Red Army Faction']
# []
# []
# []
# ['PERU', 'the Chinese Embassy']
# []
# ['FBI', 'Nabil Abuzed Mansour', 'Mohamed Shabata']
# []
# []
# []
# ['the Popular Front for the Liberation of Palestine', 'Piraeus', 'the Popular Front', 'Evgenia Angelikoussi', 'PFLP', 'Mossad', 'the PLO Liaison and Information Bureau']
# []
# ['the u.s.-financed Radio Free Europe', 'Georgescu']
# []
# ['Air France', "Abu Nidal's", 'Al Assifa', 'PLO']
# []
# ['Musi Hoti', 'Stojan Djeric', 'Redzo Zuko']
# []
# ['the Mujahedeen Khalq']
# []
# ['PLO']
# []
# []
# []
# ['Alitalia Airline', 'the Champs Elysee', 'the Armenian Movement']
# []
# ['the U.S.-run Colombo-American Institute', 'Barranquilla']
# []
# ['Boeing', 'Imam Musa Sadr']
# []
# ['PERU', 'the Ford Motor Company', 'the Bank of America', 'the Coca-Cola Company', 'the G. Berckemeyer Co.', 'the Carnation Company', 'Sendero Luminoso']
# []
# ['the United Nations', 'Andrei Gromyko', 'the jewish Defense League']
# []
# ['U.N.', 'the Thunder of Zion', 'the jewish Defense League', 'JDL']
# []
# ['Self-Defense Movement']
# []
# ['PERU', 'Sendero Luminoso']
# []
# ['the United Nations', 'Omar']
# []
# ['the Sixth Armenian Liberation Army', 'the Turkish Airlines Office', 'Copenhagen', 'ASALA', 'Martyr Hagop Darakjian Commando']
# []
# ['Swiss Embassy']
# []
# ['the Front for the Liberation of Lebanon', 'Foreigners', 'AFP', 'PLO', 'PLO']
# []
# ['PERU', 'Embassy']
# []
# ['U.S. Army']
# []
# ['Mercedes-Benz', 'the Front for the Liberation of Lebanon from Foreigners']
# []
# ['the armenian Secret Army', 'the Liberation of Armenia', 'the Geneva bureau', 'Agence France- Presse']
# []
# ['Anti-Khomeini', 'the Consul General']
# []
# ['El Al']
# []
# []
# []
# ['Belga', 'the Group of Direct Action', 'Direct Action', 'the Rue Copernic', 'Nicolas Brazzi', 'Panadryu']
# []
# ["Reader's Digest", 'the Bank of America', 'the Avis Rental Car company', 'the Communist Groups for proletarian Internationalism']
# []
# ['the Communist Groups for proletarian Internationalism']
# []
# ['the Champs-Elysees', 'Le Drugstore', 'Liberation Army of Canaque', 'authority', 'Action Directe', 'ASALA']
# []
# ['the Nicaraguan Anti-Communist Democratic Movement']
# []
# ['Gare de Lyon', 'Orly Organization']
# []
# []
# []
# ['AFP']
# []
# ['the Banque Libano Francaise', 'the Union des Assurances de Paris', 'the Orly Organization', 'ASALA', 'the Fransa Bank', 'Michael', 'the Banque Union de Paris']
# []
# ['the Orly Group of armenian']
# []
# ['Bandera', 'Etienne Bandera']
# []
# ['the Union for the total Independence of Angola', 'UNITA']
# []
# ['the Ramon Emeterio Betances', 'FMLN', 'Farabundo Marti National Liberation Front', 'Red Flag', 'Commandantes', 'Bogota Radio']
# []
# ['Paul March-Henry', 'Louis Delamare']
# []
# ['GUATEMALA', 'the security corps', 'Guatemala Frederic Chapin', "the Poor People's Guerrilla Army", 'Maximiliano Sosa Zecena', 'Guatemalan']
# []
# ['Abdul Razzak Lafta', 'Army', 'the Liberation of Kurdistan', 'AFP', 'the Iraqi Liberation Army - General Command', 'al Dawa', 'the Iraqi Embassy']
# []
# ['GUATEMALA', 'Leftist', 'the Chamber of Commerce', 'the Roque Dalton Commando']
# []
# ['Idil']
# []
# []
# []
# ['the Bakounine Gdansk Paris Group']
# []
# ['the Orly Organization', 'the Union of Banks of Paris', 'the Credit Lyonnaise', 'AFP']
# []
# ['Lufthansa Airlines']
# []
# ['the Italian Chamber of Commerce', 'ANSA', 'the Groups of Internationalist Communist']
# []
# []
# []
# ['El Espectador', 'Cali', 'Army']
# []
# ['Bakounine-Gdansk-']
# []
# ['Bakounine-Gdansk-']
# []
# ['bush']
# []
# ['El Padron Cigars', 'Jose Orlando Padron', 'the Hispania Freight Company', 'Hialeah']
# []
# ['Boeing', 'Julius Nyerere', 'Youth Democratic Movement', 'Oscar Kambona']
# []
# ['Tyre']
# []
# ['SUDAN']
# []
# ['Mohammed al-Mikdad']
# []
# []
# []
# ['Orhan Gunduz', 'the Justice Commandos']
# []
# ['ASALA', 'ASALA']
# []
# []
# []
# []
# []
# ['Agency for International Development']
# []
# ['Kani Gungor', 'the armenian Secret Army', 'the Liberation of Armenia', 'the Zaven Abedian Commando Group', 'ASALA']
# []
# ['Jew', 'Alan Goodman', 'Islam', 'Goodman', 'Goodman']
# []
# ['GUATEMALA', 'the Coca-Cola Company']
# []
# ['AUSTRIA']
# []
# ['Interior', 'Gaston Defferre', 'Al Watan', 'Al-Arabi']
# []
# ['NETHERLANDS']
# []
# ["the Revolutionary People's Struggle"]
# []
# ['Lufthansa', 'the jewish Defense League']
# []
# ['Revolutionary Cells', 'Reagan']
# []
# ['Ayatollah Khomeini']
# []
# ['PORTUGAL', 'Juan Maria Fernandez Krohn', 'John Paul', 'Msgr', 'Marcel Lefebvre', 'Paul', 'Roman Catholicism', 'the second Vatican Council', 'Fernandez', 'levebvre', 'down', 'Krohn', 'Anwar Sadat']
# []
# ['the israeli Cabinet']
# []
# ['the Red Cross International Committee', 'Marie-Jose Burnier', 'Red Cross', 'UNITA', 'the Red Cross']
# []
# ['the Bank of America', 'Direct Action']
# []
# ['the armenian Secret Army', 'the Liberation of Armenia', 'Air Canada', 'Los Angeles International Airport', "the Los Angeles Police Department's", 'FBI', 'Los Angeles Police Department', "the Los Angeles County Sheriff's Office", 'Hratch Kozibioukian', 'Stanouche Kozibioukian', 'Varant Barkev Chirinian', 'Vicken Tcharkhutian', 'Los Angeles International Airport']
# []
# ['Reagan', 'the Revolutionary Cells', 'the Red Army Faction', 'Baader-Meinhof Gang']
# []
# ["the Revolutionary People's Struggle", 'ELA', 'John Bung', 'ELA', 'Honeywell-Bull Company', 'ITT', 'ELA']
# []
# ['Shlomo Argov', 'the Palestine Liberation Organization', 'PLO', 'PLO', 'Yasser Arafat', 'Argov', 'al-Asifa', 'PLO', 'Argov']
# []
# ['PORTUGAL', 'Erkut Akbay', 'the Turkish Embassy', 'Nadid Akbay']
# []
# ['Muenster', 'Hagen/Westfalen']
# []
# ['Dusseldorf', 'Muenster', 'Hagen/Westfalen']
# []
# ['SWAZILAND', 'ANC', 'Manzini', 'Petros Nyawose', 'ANC', 'Jabu']
# []
# []
# []
# ['Pan American Airlines']
# []
# ['Mobutu']
# []
# ['Honduran Air Services', 'Nicaraguan Democratic Movement']
# []
# ['the Revolutionary Popular Struggle', 'the Atlantic Travel Agency']
# []
# ['Yugoslav Airlines', 'Cathedral']
# []
# ['David Dodge', 'the American University of Beirut', 'Dodge', 'Dodge', 'iranian Embassy', 'Mohsen Mousavi', 'Dodge', 'Moslem Amal', 'Dodge']
# []
# ['the armenian Secret Army', 'the Liberation of Armenia']
# []
# []
# []
# ['PERU', 'terrorist', 'Quimica Suiza']
# []
# []
# []
# ['AUSTRIA']
# []
# ['Babrak Karmal', 'the Afghan Army']
# []
# ['Rothschilds']
# []
# ['the Orly Group', 'Viken Charkhoudian', 'Air Canada']
# []
# ['Bakunin-Gdansk Group']
# []
# ['GUATEMALA']
# []
# []
# []
# ['PORTUGAL', 'Zionist Action Group', 'Air France', 'Lufthansa']
# []
# ['Ruth First', 'ANC', 'the Center for African Studies']
# []
# ['Museebad Singh', 'Boeing', 'Sikh', 'Akali Dal', 'Sikh', 'Sikh', 'Amritsar']
# []
# ['Pan American World Airways', 'Pan Am', 'Pan Am', 'Delta Airlines']
# []
# ['WINZ', 'Orlando Bosch']
# []
# ['terrorist', 'Bern', 'Wysocki', 'the Polish', 'Revolutionary Home Army', 'florian Kruszyk', 'Krystof Wasilewski', 'Miroslaw Plewinski', 'Marck Michalski']
# []
# ['the Red Brigades', 'SIMA']
# []
# ['Amos Man-El', 'Zoltan Mandel-Schmidt', 'Veronica', 'Palestine Liberation Organization', 'the Armed Factions']
# []
# ['the Cinchonero National Liberation Movement', 'the Chamber of Commerce', 'Cabinet', 'Central American Democratic Community', 'Alejandro Montenegro']
# []
# []
# []
# ['the israeli Embassy', 'Hayin Aharon', 'M-19']
# []
# ['Alia']
# []
# ['the U.S. Army']
# []
# ['an israeli Army', 'Alayh', 'Al-Bika', 'the Popular Front for the Liberation of Palestine']
# []
# ['U.S. Army']
# []
# []
# []
# ['U.S. Pigs']
# []
# []
# []
# ['the Communist Metropolitan Front']
# []
# []
# []
# ['the National Union for the total Independence of Angola', 'UNITA', 'UNITA']
# []
# []
# []
# ['the American Cultural Center']
# []
# ['Torah', 'PLO']
# []
# ['GUATEMALA', 'Roberto Suazo', 'Xiomara Suazo Estrada', 'the Pedro Dias Command of the Ixim (mayan', "People's Revolutionary Movement", 'Suazo']
# []
# ['IBM', 'White Plains', 'IBM', 'IBM', 'the South African Railways Procurement Office']
# []
# ['U.N.', 'U.N.']
# []
# ['the Armenian Popular Movement', 'the Liberation of Armenia', 'ASALA', 'ASALA']
# []
# ['AFGHANISTAN', 'Mazar-i-Sharif']
# []
# ['anti-castro']
# []
# ['CYPRUS']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['the American Embassy', 'ETA']
# []
# ['the dutch Militant Autonomous Front']
# []
# []
# []
# ['Aeroflot Soviet Airlines', 'Defense League']
# []
# ['PAKISTAN', 'Air France', 'Mujahidin']
# []
# []
# []
# ['Standard Electric']
# []
# ['PERU', 'outside Ayacucho Department', 'Sendero Luminoso']
# []
# ['State', 'Abdul Aziz Hussein', 'Kuwaiti Airways Corp.', 'Hussein']
# []
# ['PLO', 'Mossad', 'PLO']
# []
# ['Islamic Holy War']
# []
# []
# []
# ['UGANDA', 'Suspected National Resistance Army']
# []
# ['the 2 April Group', 'Giacchino Commnand', 'Margaret Thatcher', 'U.S. Navy']
# []
# ['CYPRUS']
# []
# ['Nelida Anaya Montes', 'Ana Maria', 'Marxist Popular Liberation Forces']
# []
# ['Embassy', "People's Revolutionary Solidarity Organization", "People's Revolutionary Struggle", 'the U.S. Embassy', 'the israeli Army']
# []
# ['the U.S. Embassy', 'the Islamic Jihad Organization (Islamic Holy War', 'Jihad', 'Amal', 'Baalbek', 'Baalbek', 'Khomeini', 'death']
# []
# ['GRENADA']
# []
# ["the Group for Martyred 'Isam as-Sartawi", 'PLO', 'Army', 'National Liberation', 'Khomeyni']
# []
# ['Albert Schaufelberger', 'the Central American University', 'University', 'Schaufelberger', 'Radio Venceremos', 'Farabundo Marti National Liberation Front', 'Elizabeth Ramirez', 'Yankee', 'the Popular Liberation Forces', 'FPL', 'FMLN']
# []
# ['PERU', 'Sendero Luminoso', 'sl', 'the U.S. Embassy', 'the Sheraton Hotel', "the Bayer Chemical Corporation's", 'Bayer', 'SL', 'Bayer']
# []
# ['Palestine Liberation Organization', 'the Lebanese National Resistance Front', 'PLO']
# []
# ['Michelin']
# []
# ['U.S. Embassy']
# []
# ['PLO', 'Yasser Arafat', 'PLO', 'Arafat', 'Ezzedin Sherif']
# []
# ['Polaroid', 'the libyan Arab Airways', 'Radja Aref Akmed', 'Hasan Mahti', 'Saadoun Hajj', 'Imam Musa Sadr', 'Sadr', 'the Black beret']
# []
# ['Mark Frohardt', 'CIA', 'Borders', 'Frohardt']
# []
# ['the Interior Ministry Building', 'Rodrigo Cuadra', 'the Democratic Revolutionary Alliance', 'Francisco Morales Leal', 'ARDE']
# []
# []
# []
# ['Yokosuka', 'Army']
# []
# ['the British Council']
# []
# ['the armenian Secret Army', 'the Liberation of Armenia', 'ASALA', 'Garbidjian']
# []
# []
# []
# ['Betancur', 'Paolo Lugari', 'the colombian Government', 'Lugari', 'State Security Service', 'Lugari', 'Julio Pena', 'William de Jesus Parra']
# []
# ['Jari', 'Terre des Hommes (Land of Man', "the Tigre People's Liberation Front"]
# []
# ['the Ahmaddiya Movement', 'Islam', 'AMI', 'Defense League']
# []
# ['Air France', 'TNT']
# []
# ['the British Embassy']
# []
# ['American Express', 'American Express']
# []
# ['the Philippine Embassy']
# []
# ['Leumi Bank', 'Oxford Circus']
# []
# ['anti-castro', 'Orlando Bosch']
# []
# ['ASALA']
# []
# []
# []
# ['Marseilles', 'Charles Martel']
# []
# []
# []
# ['the U.S. Embassy']
# []
# ['TNT']
# []
# ['the Committee for liquidation of Computers', 'Sperry-Univac Company', 'Sperry-Univac']
# []
# ['PERU', 'Sendero Luminoso', 'the Sheraton Hotel', 'the Interamerican Press Association']
# []
# ['the Chase Manhattan Bank']
# []
# ['Tyre']
# []
# ['facility']
# []
# ['the saudi Arabian Airlines']
# []
# ['Revolutionary Organization', 'U.S. Navy', 'George Tsantes', 'CIA', 'Richard Welch']
# []
# ['Honeywell']
# []
# ['the U.S. target', 'National Cash Register Company', 'Coca Cola', 'Texaco', 'IBM', 'NCR', 'IBM']
# []
# ['National Cash Register Company', 'Coca Cola', 'Texaco', 'IBM', 'NCR', 'IBM']
# []
# ["Yasser Arafat's", 'PLO', 'anti-arafat PLO']
# []
# ['KUWAIT', 'Islamic Holy War']
# []
# []
# []
# []
# []
# ['the Jordanian Embassy']
# []
# ['PERU', 'Sendero Luminoso', 'Cobriza']
# []
# ['the South African Embassy']
# []
# ['Islamic Jihad', 'the saudi Arabian Embassy', 'Hussein Farrash']
# []
# ['the U.S. McGraw Army Barracks', 'the Revolutionary Cells']
# []
# ['SUDAN', 'Chevron Oil Company']
# []
# ['Gholam Ali Oveissi', 'Oveissi', 'pro-royalist', 'Ayatollah Khomeini', 'the Islamic Jihad', 'Ayatollah Khomeini', 'the Revolutionary Iranian Organization for Liberation and Reform']
# []
# ['Frank Regier', 'the Islamic Jihad']
# []
# ['Leamon Hunt', 'Hunt', 'Fiat', 'Hunt', 'the Fighting Communist Party', 'the Red Brigades', 'the Sinai Pact', 'NATO', 'LARF', 'the Red Brigades']
# []
# ['Jordan', 'Qaddafi', 'the Jordanian Embassy', 'Sami Shamayleh']
# []
# ['the democratic Front for the Liberation of Palestine', 'DFLP']
# []
# ['Jeremy Levin', 'Cable News Network', 'the Islamic Jihad', 'Levin', 'the Islamic Jihad']
# []
# []
# []
# ['France Center']
# []
# ['PERU', 'the U.S. Embassy', 'the Sheraton Hotel']
# []
# ['the Black Liberation Army']
# []
# ['the Revolutionary Organization of Socialist Moslems', 'Whitty', 'Whitty', 'the British Council']
# []
# ['the Nicaraguan Democratic Force', 'FDN', 'the Democratic Revolutionary Alliance', 'ARDE', 'FDN', 'CIA']
# []
# ['the Nicaraguan Democratic Force', 'FDN', 'the Democratic Revolutionary Alliance', 'ARDE', 'FDN', 'CIA']
# []
# ['the Nicaraguan Democratic Force', 'FDN', 'the Democratic Revolutionary Alliance', 'ARDE', 'FDN', 'CIA']
# []
# ['the libyan Embassy', "a People's Bureau"]
# []
# ['the African National Congress', 'ANC', 'Transkei', 'ANC']
# []
# ['Islamic Jihad', "Wa'd", 'Cambio']
# []
# ['the libyan Embassy', 'the libyan Embassy', 'the British Embassy']
# []
# ['Sony', 'Sonauto']
# []
# ['ETA', 'Anti-Terrorist Liberation Group', 'ETA']
# []
# ['the Anti-armenian Organization']
# []
# ['Amnesty International']
# []
# ["the People's Liberation Army", 'the Eelam Tigers', 'Tamil', 'Government']
# []
# ['the Anglo American Corporation', 'ANC']
# []
# ['Cali', 'the U.S. Embassy', 'the Revolutionary Armed Forces', 'SAHSA']
# []
# ['Eden Pastora', 'ETA', 'the London Times', 'Roberto Gaguine']
# []
# ['NORTHERN', 'british Army', 'the British Army']
# []
# ['Sikh']
# []
# ['ETA']
# []
# ['PLO', 'Arafat', 'the  Palestine Liberation Organization', 'PLO', 'Yasser Arafat']
# []
# []
# []
# ['the Perito Moreno', 'Belgrano', 'Shell Oil Company', 'the Sargento Cisneros Commando', 'Shell']
# []
# ['Umaru Dikko', 'Dikko', 'Nigerian Airways']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['the National Union for the total Independence of Angola', 'UNITA', 'Gulf Oil Company', 'UNITA']
# []
# ['pro-castro Army of National Liberation']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['Islam', 'Air France', 'Shapur Bakhtiar']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['U.S. Embassy']
# []
# ['Coca-Cola', 'the Manuel Rodriguez Patriotic Front']
# []
# ['ETA', 'Renault']
# []
# ['Yitzhak Shamir', 'Herut Party', 'Palestine Liberation Organization']
# []
# []
# []
# ['Indian Airlines', 'Sheik Mohammed bin Rashid alMaktoum', 'Sikh', 'the Indian Army', 'Sikh']
# []
# ['ETA']
# []
# []
# []
# ['Maputo', 'the Mozambique National Resistance Front']
# []
# ['the Islamic Jihad']
# []
# ['the Suez Canal', 'Amoco', 'Standard Oil of Indiana', 'Olympic Energy', 'Islamic Jihad']
# []
# ['CYPRUS', 'libyan Embassy']
# []
# []
# []
# ['Litton Business Systems', 'Litton Industries', 'the Communist Combatant Cells', 'Litton']
# []
# ['PLO']
# []
# ['the National Liberation Army']
# []
# ['PORTUGAL', 'ETA', "the French Government's", 'ETA']
# []
# ['the Associated Press news agency']
# []
# ['the British High Commission']
# []
# []
# []
# ['Brittany']
# []
# ['the west German Mannesmann Company']
# []
# ['Embassy']
# []
# ['ETA']
# []
# []
# []
# ['Western India', 'Perry Norris', 'the Revolutionary Organization of Socialist Moslems', 'Kenneth Whitty']
# []
# ['Hansa', 'MIR']
# []
# ['PERU', 'the Sendero Luminoso', 'the peruvian-American Cultural institute']
# []
# ['Iraqi Embassy', 'Islamic Action']
# []
# ['PORTUGAL', 'the Popular Forces of April 25', 'the North Atlantic Treaty Organization']
# []
# ['the North Atlantic Treaty Organization', 'NATO', 'the Communist Combatant Cells', 'NATO']
# []
# ['Palestine Liberation Organization', 'PLO']
# []
# ['CALEDONIA']
# []
# ['the Turkish Consulate General']
# []
# ['jordan', 'Arafat']
# []
# ["the French Embassy's", 'the Red Army Faction', 'RAF']
# []
# ['Army', 'Ramlet al-Baida', 'ASALA']
# []
# ['the Meyer Institute']
# []
# ['Zaven Karagozian', 'Dashnak Party', 'Armenian Revolutionary Federation']
# []
# ['Ford', 'Revolutionary Caribbean Alliance']
# []
# ['the Islamic Jihad', 'NATO']
# []
# ['the Lloyd Boliviano Airlines Boeing', 'Armando Guerra Perez']
# []
# []
# []
# ['the National Front', 'Greeks', 'Carlos']
# []
# ['Leftist', 'Union Carbide', 'Xerox', 'IBM', 'General Telephone and Electronics', 'IBM', 'the National Army of Liberation', 'the Ricardo Franco Front', 'the Revolutionary Armed Forces of Colombia', 'FARC']
# []
# ['Cyprus Airways', 'the Black Brigade']
# []
# ['Shaul Zehavi', 'Bazouriyeh']
# []
# ['the Bolivian-American Bank']
# []
# ['Qaddafi']
# []
# ['CIA', 'Reagan', 'CIA', 'CIA']
# []
# ...
# []
# []
# []
# []
# []
# ['the Imad Mughniyeh Groups', "the al-Aqsa Martyrs'", 'Brigades', 'Sederot', 'al-Aqsa', "Salim Jum'a al-Hamidi", 'israeli Forces', 'Hamas', 'Fatah']
# []
# ['Jar Allah']
# []
# []
# []
# ['al-Aiadhiya', 'Tal Afar']
# []
# ['Afghani', 'Taliban']
# []
# []
# []
# ['Adhamiya']
# []
# ['USPI', 'USPI']
# []
# []
# []
# ['Afghani']
# []
# ['iraqi Army', 'Saad']
# []
# ['Mahbun Elahi', 'Pol-e Alam']
# []
# ['Yala', 'Pattani']
# []
# ['Yala', 'Pattani']
# []
# ['Malok', 'Taliban']
# []
# []
# []
# []
# []
# []
# []
# ['ETA', 'ETA', "Constitutional Court's"]
# []
# []
# []
# ['Taliban']
# []
# []
# []
# ['Essa al-Dulaim']
# []
# []
# []
# []
# []
# ['Taliban']
# []
# ['Ahmedabad', 'gelatin']
# []
# ['Ahmedabad', 'gelatin']
# []
# ['Harkat-ul-Jihad-al-Islami']
# []
# ['Harkat-ul-Jihad-al-Islami']
# []
# ['Harkat-ul-Jihad-al-Islami']
# []
# ['Harkat-ul-Jihad-al-Islami']
# []
# ['Moro Islamic Liberation Front', 'Cotabato', 'Aleosan', 'the Moro Islamic Liberation Front']
# []
# ['Zaki Obaid Fayadh', 'the Iraqi Islamic Party', 'Zaki Obaid Fayadh', 'Dhubbat']
# []
# ['Orio', 'ETA']
# []
# ['Al Qaeda']
# []
# ['Layeq Manzel', 'Manzel', 'Manzel']
# []
# []
# []
# ['Development Alternatives, Inc.']
# []
# ['Qayara', 'the Islamic State of Iraq', 'al-Qaida']
# []
# []
# []
# ['Taliban']
# []
# ['qat', 'Beledweyene']
# []
# ['the Animal Liberation Front']
# []
# ['7-Eleven', 'Kumpulan Kecil', 'RKK', 'the Barisan Revolusi Nasional Coordinate', 'BRN Coordinate', 'RKK', 'RKK']
# []
# ['Carrefour', '7-Eleven', 'Kumpulan Kecil', 'RKK', 'the Barisan Revolusi Nasional Coordinate', 'BRN Coordinate', 'RKK', 'RKK']
# []
# []
# []
# ['Taliban', 'Taliban']
# []
# ['Dost Mohammad', 'Mohammad', 'Tatank', 'Taliban']
# []
# ['the Movement for the Emancipation of the Niger Delta', 'MEND', "the People's Democratic Party", 'PDP', 'Ondo State', 'MEND', 'MEND']
# []
# ['Taliban', 'the National Security Department', 'Nur Khan', 'Khan', 'Taliban']
# []
# ['PKK', 'Malazgirt']
# []
# ['Kariye']
# []
# ['Mahmoud Younis', 'the Iraqi Islamic Party', 'Younis', 'al-Mashahda', 'the Imam Basher mosque', 'Sunni Endowment']
# []
# ["al-Qa'ida"]
# []
# ['Tal Afar', 'Tal Afar', 'authority', 'Tal Afar']
# []
# ['Taliban', 'Radio Voice of Freedom', 'Taliban']
# []
# ['Xinhua', 'Uyghurs', 'Xinhua', 'Uyghurs', 'Turkic', 'Uyghur', 'Uyghurs', 'the Turkestan Islamic Party']
# []
# []
# []
# ['Tak Bai']
# []
# ['Ghazni', 'Mohammad Osman Osmani', 'Taliban']
# []
# []
# []
# ['Taliban']
# []
# ['Bouira', 'Tizi Oujaboub']
# []
# ['al-Qayara']
# []
# ['Taliban']
# []
# []
# []
# ['Ashqelon']
# []
# ['Yala']
# []
# ['FARC']
# []
# ['Raza Azimian', 'Hassan Farsi', 'Islam Qala']
# []
# []
# []
# ['al-shabaab shot', 'Usman Ali', 'Al-Shabaab']
# []
# ['Malaga', 'ETA', 'ETA']
# []
# ['Paramananda Jha', 'Jha']
# []
# ['Farm Hada']
# []
# ['Moro Islamic Liberation Front', 'the Moro Islamic Liberation Front']
# []
# ['Faris Jabir Dhahir', 'al Zaafaraniya', 'Shahid al-Mihrab Foundation', 'Abdelaziz al-Hakim', 'the Supreme Islamic Iraqi Council', 'Unified Iraqi Council']
# []
# []
# []
# []
# []
# ['Beni Bechir']
# []
# ['Taliban']
# []
# ['the Pakistan Ordnance Factory', 'the Pakistan Ordnance Factory', 'Tehrik', 'Taliban', 'NWFP']
# []
# ['Islamist Forest Brothers']
# []
# ['Muhammad Isa Diriye', 'Wadajir', 'Hasan']
# []
# ['Taliban']
# []
# ['the Awakening Council', 'Aziz Moklif Ghatha al-Zubai', 'the Awakening Council', 'Al-Zaidan', 'Al-Zaidan', 'Al-Qaeda', 'Al Qaeda', 'Awakening Council']
# []
# ['Haider al-Saymari', 'Ali al-Sistani', 'Al-Saymari']
# []
# []
# []
# ['the National Defense Supreme Council of the Armed Forces']
# []
# ['World Food Program', 'WFP', 'Ali Nasir']
# []
# ['the Palace of Justice', 'the Palace of Justice', 'the Aristi Hotel', 'FARC']
# []
# ['the Kendi Hospital']
# []
# ['Yala']
# []
# ['Ahmed al-Chalabi', 'Chalabi', 'Chalabi', 'Chalabi']
# []
# ['al-shabaab', 'Parliament', 'Adan Madobe', 'Madobe', 'mortar']
# []
# []
# []
# ['Taliban', 'Ghashi']
# []
# []
# []
# ['Shaskarak']
# []
# ['Jawad al-Hattab', 'al-Arabiyah Bureau']
# []
# ['NWFP', 'Taliban']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['the World Health Organization', 'Spin Boldak', 'Taliban']
# []
# ['Ugandan', 'the African Union', 'the Transitional Federal Government', 'TFG', 'Al-Shabaab']
# []
# ['the Movement for the Emancipation of the Niger Delta', 'MEND', "Royal Dutch Shell's", 'Royal Dutch Shell', "Chevron Corporation's"]
# []
# ['Taliban']
# []
# ['ETA']
# []
# ['Defense', 'Robert Gates', 'General Petraeus to Lieutenant General', 'Ray Odierno']
# []
# ['FARC']
# []
# ['Esam al-Timimi', 'al-Jadida']
# []
# ['Thailand脮s Yala']
# []
# ['Sari-Solenzara']
# []
# ['the Marriott Hotel', 'Zardari', 'the Marriott Hotel', 'Taliban', 'Harkat-ul-Jihad-al-Islami']
# []
# ['Moro Islamic Liberation Front', 'Maguindanao', 'MILF', 'Mindanao', 'AFP', 'MILF']
# []
# ['Ghassan Redha', 'the Finance Ministry']
# []
# []
# []
# ['ETA']
# []
# ['Zaafarnaiya']
# []
# ['Zeev Sternhell']
# []
# []
# []
# ['National Directorate of Security', 'Jaji Maydan']
# []
# ['bahawalpur']
# []
# ['al-Aqsa Brigades', 'Fatah']
# []
# ['the Spin Boldak District', 'Taliban']
# []
# []
# []
# []
# []
# []
# []
# ['Maharaja Ganju Bazar']
# []
# ['Pasthun', 'Asfandyar Wali Khan', 'Khan', 'Awami National Party', 'the Awami National Party', 'Taliban']
# []
# ['Surigao de Norte', 'MILF', 'Moro Islamic Liberation Front']
# []
# ['Ibrahim Shaykh', 'Shaykh', 'the Mujahideen Youth Movement', 'Ibrahim Shaykh']
# []
# []
# []
# ['the Mujahideen Youth Movement', 'Parliament']
# []
# ['Muhammad Ise Diriye', 'the International Committee of the Red Cross', 'Diriye', 'ICRC']
# []
# []
# []
# ['the Chart Thai party']
# []
# ['Al-Shabaab', 'Abdullahi Yusuf Ahmad', 'Hasan Kafi', 'mortar']
# []
# ['the Freedom Hawks', 'Roni Vengeance Brigade', 'the Kurdish Workers Party']
# []
# ['Taliban', 'Taliban']
# []
# []
# []
# ['Taliban']
# []
# ['Gange', 'Taliban']
# []
# []
# []
# []
# []
# ['Taliban']
# []
# ['Taliban', 'NATO']
# []
# []
# []
# ['Taliban']
# []
# []
# []
# []
# []
# ['Mehmet Yasar', 'Development Party']
# []
# []
# []
# ['Taliban', 'SERVE', 'Gayle Williams', 'Taliban', 'Williams', 'Williams']
# []
# []
# []
# ['the Hezb-e Eslami', 'Wardak']
# []
# ['Santander Bank']
# []
# ['FARC']
# []
# ['Royal Dutch Shell', 'Revolutionary Struggle', 'the US Embassy']
# []
# ['Euskotren', 'ETA']
# []
# ['Abdul Karim Hassan', 'Awakening Council', 'Al Qaida', 'Hassan', 'Hassan']
# []
# ['FARC', 'Medio Atrato Municipality', 'FARC']
# []
# []
# []
# ['the Legitimate Defense Group']
# []
# ['TNT', 'Thai Constitutional Court']
# []
# ['Guwahati', 'Pan Bazar', 'Fancy Bazar', 'RDX', 'the United Liberation Front of Assam', 'Harkat-ul-Jihad-al-Islami']
# []
# ['RDX', 'the United Liberation Front of Assam', 'Harkat-ul-Jihad-al-Islami']
# []
# ['Taliban']
# []
# ['the Mujahideen Youth Movement', 'Hassan Bikulu', 'Bikulu']
# []
# []
# []
# ['Amitie-Franco-Afghane', 'the Afghan National Intelligence', 'Mr Egreteau', 'Egreteau']
# []
# ['Moro Islamic Liberation Front', 'Tabalao', 'MILF', 'Moro Islamic Liberation Front']
# []
# []
# []
# ['Tambon Kabang']
# []
# ['the Aynak Copper Mine', 'Taliban']
# []
# ['Hamas', 'Qassam', 'Kibbutz Nir Yitzhaq', 'al-Qassam']
# []
# ['Hamas', 'Qassam', 'Kibbutz Yad Mordekhay', 'Mefasim', 'Kibbutz Ziqim', 'Kibbutz Erez', 'al-Qassam']
# []
# ['Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'Sumud', 'Sederot', 'Negev']
# []
# []
# []
# ['al-Shabaab', 'the Presidential Palace', 'the Presidential Palace']
# []
# ['the Hezbollah Brigades', 'Sederot']
# []
# ['Mahmud Muhammad Usman']
# []
# ["Muhammad Ma'alin Osman", 'Osman']
# []
# []
# []
# ['Fatah', 'al-Aqsa Brigades', 'Kibbutz Keffar Azza']
# []
# []
# []
# ['Mustafa Kemal Ataturk', 'Hakkari']
# []
# ['the Government House', 'PAD', "People's Alliance for democracy"]
# []
# []
# []
# ['Taliban']
# []
# []
# []
# ['Taliban', 'Taliban']
# []
# ['Fatah', 'al-Mujahidin', 'Sederot']
# []
# ['the European Union', 'EU', 'the Kosovar Government']
# []
# ['Ayman Jidah', 'the al-Aqsa Brigades', 'Fatah', 'Sederot']
# []
# ['the National Theater']
# []
# ['Salah al-DIn', 'Brigades', 'Sederot', 'Sederot']
# []
# ['Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'al-Quds Brigades of Islamic Jihad', 'Sederot', 'Sederot']
# []
# ['Al-Shabaab']
# []
# ['Awakening Council']
# []
# ['the Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'Sumud', 'Sederot']
# []
# ['a Provisional Reconstruction Team']
# []
# ['the Democratic Front for the Liberation of Palestine', 'Ashqelon']
# []
# ['Constantine', 'Palace of Justice', 'Constantine']
# []
# ['Arnotegi Hill', 'ETA']
# []
# ['the Popular Front for the Liberation of Palestine', 'Martyr Abu Ali Mustafa Brigades', 'Sumud', 'Sederot']
# []
# []
# []
# ['the Popular Front for the Liberation of Palestine', 'Ashqelon']
# []
# []
# []
# ['Uqba bin Nafie Square']
# []
# []
# []
# ['Trade Ministry', 'sofa']
# []
# ['Taliban']
# []
# ['Moro Islamic Liberation Front']
# []
# ['Lashkar-e-Taiba']
# []
# ['Lashkar-e-Taiba']
# []
# []
# []
# []
# []
# ['astv (Asia Satellite Television']
# []
# ['Mohammad Yagub', 'Kapisa', 'Taliban']
# []
# []
# []
# []
# []
# ['Al-Shabaab', 'Ahmed Daci', 'Wadajir']
# []
# ['Negev']
# []
# []
# []
# ['Mudhir al-Mawla', 'al-Mawla']
# []
# ['Ashqelon']
# []
# ['Diphu', 'the Karbi Longri N.C.']
# []
# []
# []
# ['al-shabaab']
# []
# ['Negev']
# []
# ['Al-Julan', 'Al Qaeda', 'the Islamic State of Iraq']
# []
# []
# []
# ['Fatah', 'al-Aqsa Martyrs', 'Jaysh al-Buraq', 'Sederot']
# []
# ['Vakfibank']
# []
# ['FARC', 'the Colombian Welfare Institute', 'ICBF', 'FARC']
# []
# []
# []
# ['farc', 'del Guaviare', 'El Retorno', 'El Retorno']
# []
# ['Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'Fatah', 'al-Aqsa Martyrs Brigades-Martyr', 'Nabil', 'Ashqelon']
# []
# ['MSF', 'Gaalkacyo', 'MSF']
# []
# []
# []
# ['Saudi Airlines', 'Ekhvan al-Redvan']
# []
# ['the Mirwais Hospital', 'Taliban']
# []
# ['Sahar Gol', 'Ghazni']
# []
# ['Ahmad Khamis', 'the Awakening Council', 'Khamis', 'Al Qaida']
# []
# ['Taliban']
# []
# ['Raid Fahmi', 'Sciences and Technology', 'Babel Hotel', 'Fahmi']
# []
# ['al-Quds Brigades', 'Ashqelon']
# []
# []
# []
# ['Guido Guardia', 'Gerald']
# []
# ['al-Quds Brigades of Islamic Jihad', 'Sederot']
# []
# ['the Moro Islamic Liberation Front']
# []
# ['Abdol Ghafur', 'Jagharo', 'Taliban']
# []
# ['al-Quds Brigades of Islamic Jihad', 'Sederot']
# []
# ['Yala']
# []
# ['al-Quds Brigades of Islamic Jihad', 'Sederot']
# []
# ['Islamic Jihad', 'Ashqelon']
# []
# ['al-Aqsa Brigades', 'Fatah', 'Sederot']
# []
# ['the Moro Islamic Liberation Front', 'MILF']
# []
# ['the Presidential Palace', 'Bakaaraha Market']
# []
# ['Hamas']
# []
# ['the Moro Islamic Liberation Front', 'MILF']
# []
# ['Fatah', 'al-Aqsa Brigades', 'Sederot']
# []
# ['Hamas', 'Qassam', 'grad']
# []
# []
# []
# ['Anglet', 'the the Basque Country']
# []
# ['the Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'Sumud', 'Sederot']
# []
# ['Sederot']
# []
# ['the Philippines Armed Forces Western Mindanao Command', 'the Abu Sayyaf Group', 'Abu Sayyaf Group', 'Sulu']
# []
# ['Taliban']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Qassam', 'grad', 'Ashqelon']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Sederot']
# []
# ['the Abu Ali Mustafa Brigades', 'the Popular Front for the Liberation of Palestine', 'Karab Abu Salim']
# []
# ['al-Quds Brigades of Islamic Jihad', 'Ashqelon']
# []
# ['the Izz al-Din al-Qassam Brigades', 'Hamas', 'grad']
# []
# ["Isma'il Hasan Timir", 'Shaykh Adan Muhammad Nur', 'the Somali Parliament']
# []
# ['Fatah', 'Ashqelon']
# []
# ['a National Assembly Seat', 'Tehrik']
# []
# ['the Parwan Province Government', 'Charikar', 'Gulbuddin Hekmatyar']
# []
# ['the Izz al-Din al-Qassam Brigades', 'grad']
# []
# ['the Izz al-Din al-Qassam Brigades', 'Qassam', 'Sederot']
# []
# ['the Izz al-Din al-Qassam Brigades']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Ashqelon']
# []
# ['al-Quds', 'Islamic Jihad', 'Keffar Azza']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'grad', "Be'er Sheva"]
# []
# ['the Eagles of Palestine Brigades', 'Ashqelon']
# []
# []
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Qassam']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'grad']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'grad']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Qassam', 'Sederot']
# []
# ['Hamas', 'Izz al-Din al-Qassam Brigades', 'Qassam']
# []
# ['Yala']
# []
# []
# []
# ['Hamas', 'Qassam']
# []
# ['Hamas', 'grad', 'Hatzerim']
# []
# ['the National Resistance Brigades of the Democratic Front for the Liberation Front for the Liberation of Palestine', 'Muqawamah', 'Nahal', "Kibbutz Sa'ad", 'Ashqelon', 'Sederot']
# []
# ['Ashqelon', 'Ashqelon']
# []
# []
# []
# ['Hamas', 'Qassam', 'Sederot', 'Ziqim']
# []
# ['Hamas', 'grad']
# []
# ['Hamas', 'Qassam', 'Ashqelon']
# []
# ['Hamas', 'Qassam']
# []
# []
# []
# ['the World Food Program', 'WFP', 'WFP', 'killing', 'WFP']
# []
# ['Taliban']
# []
# ['Haji Gol', 'Gol', 'Hamid Karzai', 'Ahmad Wali Karzai', 'Taliban']
# []
# ['the German Embassy', 'Camp Eggers', 'Taliban', 'Shamsul Rahman', 'the German Embassy']
# []
# []
# []
# ['Shahr', 'Mohammad Afzal']
# []
# ['Taliban', 'Karamkhel']
# []
# []
# []
# []
# []
# []
# []
# ['Ghazi Khan']
# []
# ['Abdol Aziz', 'the Dubai Hotel']
# []
# ['Maj', 'Mohammad Nader', 'Taliban']
# []
# ['the Campos de las Naciones', 'ETA', 'ETA']
# []
# ['the Ministry of Justice', 'Justice Department', 'Taliban', 'Taliban']
# []
# ['Taliban']
# []
# ['the Revolutionary Struggle']
# []
# ['Badiuzzaman Sabri', 'Nader Shah Kot District', 'Taliban']
# []
# ['Taliban']
# []
# ['Citibank', 'the Revolutionary Struggle']
# []
# ['Sarfaraz Khan', 'the tribal council for the Greshk district']
# []
# ['Anglet', 'Irrintzi']
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['Citibank', 'Citibank', 'the Revolutionary Struggle']
# []
# ['Taliban']
# []
# ['Villavicencio', 'FARC']
# []
# ['the Imam Sahib District', 'Taliban']
# []
# ['the Qala Kashaf School']
# []
# ['Taliban']
# []
# ['the Public Estate Corporation', 'the General Athens Police Directorate', 'the Public Estate Corporation', 'the Revolutionary Struggle']
# []
# []
# []
# []
# []
# ['Haji Wazir', 'the Gardez-Zormat Road', 'Taliban']
# []
# ['FARC', 'FARC']
# []
# ['Taliban']
# []
# []
# []
# ['Thessaloniki']
# []
# ['Mullah Nur']
# []
# ['Taliban']
# []
# []
# []
# ['Lolaki']
# []
# ['Thessaloniki']
# []
# ['Syed Khan', 'Taliban']
# []
# ['Taliban']
# []
# []
# []
# ['Khuja Mohammad Hissah']
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['Abdol Zaher']
# []
# []
# []
# []
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['the Public Power Corporation', 'the Vengeance Nucleus', 'Revolutionary Struggle']
# []
# ['Taliban']
# []
# ['Taliban']
# []
# ['Zmaray']
# []
# ['Taliban']
# []
# ['Andijan', 'the Islamic Jihad Union', 'the IMU (Islamic Movement of Uzbekistan']
# []
# []
# []
# ['World Food Program', 'Taliban']
# []
# ['the Education Ministry', 'Rafael Correa', 'Teleamazonas']
# []
# ['Eng Mohammad Omar']
# []
# ['Abdulhakim Muhammad', 'United Soldiers', 'Army', 'Muhammad', 'Muhammad', 'Muhammad']
# []
# ['Laskhargah']
# []
# ['FARC']
# []
# ['Janan', 'Taliban']
# []
# ['Taliban']
# []
# ['vbied']
# []
# []
# []
# ['ANFO', 'FARC']
# []
# ['Mohammad Nazim Jamil', 'Shir Khan Dry Port', 'Taliban']
# []
# ['Taliban']
# []
# ['United Stated Protection and Investigation', 'Taliban']
# []
# ['Abdol Khaleq']
# []
# ['Hajji Akbar Khan']
# []
# ['NGO', 'Hesar', 'the UN Agency for Refugees in the area', 'Taliban']
# []
# ['Taliban']
# []
# ['the Konar Security Command', 'Zarjan']
# []
# []
# []
# []
# []
# ['Mazar-e Sharif']
# []
# ['the dutch Aid Agency', 'HealthNet TPO', 'HealthNet TPO']
# []
# []
# []
# []
# []
# ['the Angar Organization', 'Chakawa', 'the Angar Organization', 'Taliban']
# []
# ['Sayed Fazlollah Wahedi', 'Taliban']
# []
# []
# []
# ['Rajab Khan', 'Taliban']
# []
# ['a Provisional Reconstruction Team', 'Taliban']
# []
# ['Malak Niaz', 'Niaz', 'Taliban']
# []
# ['the Najib Gorboz Road Construction Company', 'Nurkil']
# []
# ['Gardez', 'Intelligence Directorate', 'Intelligence Directorate', 'Taliban']
# []
# ['Hazar Sim', 'Roy', 'NGO']
# []
# []
# []
# ['the Revolutionary Struggle']
# []
# ['Ghulam Mohammad', 'Mohammad', 'Taliban']
# []
# ['Hamid Karzai']
# []
# ['the Civil Guard', 'Calvia', 'Mallorca', 'ETA']
# []
# []
# []
# ['Palma de Majorca', 'Enco', 'ETA']
# []
# ['Jairo Martinez Solarte', 'Martinez Solarte', 'farc.authoritie', 'FARC']
# []
# ['House', 'Santander de Quilichao', 'ANFO', 'FARC']
# []
# ['the Khyber Agency', 'Taliban']
# []
# ['TNT']
# []
# ['KRKO', 'the Earth Liberation Front']
# []
# ['Londonderry']
# []
# ['FARC', 'Norte de Santander Municipality', 'FARC']
# []
# ['NWFP', 'Sardar Hussain Babak']
# []
# ['the PASOK Party']
# []
# ['the Northwest Frontier Region', 'Bannu', 'Taliban']
# []
# ['the New Democracy Party']
# []
# []
# []
# ['International Islamic University']
# []
# ['sur Gol Khan', 'the Afghan Independent Election Commission']
# []
# ['UNDP', 'UNDP', 'the Ethiopian Consulate']
# []
# ['the Animal Liberation Front']
# []
# ['the Corsican National Liberation Front (FLNC']
# []
# ['Ireland Policing Board']
# []
# ['Taliban', 'Dawa Khan Menapal', 'Radio Free Europe/Radio Liberty', 'Aziz Popal']
# []
# ['Thessaloniki']
# []
# ['FARC']
# []
# ['FARC']
# []
# ['FARC', 'Guapi']
# []
# ['FARC']
# []
# ['FARC', 'Caqueta']
# []
# []
# []
# defaultdict(collections.Counter, {})

# %%
import pandas as pd
df = pd.DataFrame.from_dict(dict(count_dict), dtype=int)
df = df.fillna(value=0).astype(int)
df
